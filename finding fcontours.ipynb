# %%
# %tensorflow_version 2.x
# Out:
# TensorFlow 2.x selected.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
pip install --upgrade pip
# Out:
# ...
#      |████████████████████████████████| 1.4MB 9.0MB/s
# ...
#   Found existing installation: pip 19.3.1
#     Uninstalling pip-19.3.1:
#       Successfully uninstalled pip-19.3.1
# ...

# %%
from PIL import Image
import matplotlib.pyplot as plt
import numpy as np
import keras
from keras.models import load_model
import cv2
# Out:
# Using TensorFlow backend.
# <p style="color: red;">
# The default version of TensorFlow in Colab will soon switch to TensorFlow 2.x.<br>
# We recommend you <a href="https://www.tensorflow.org/guide/migrate" target="_blank">upgrade</a> now
# or ensure your notebook will continue to use TensorFlow 1.x via the <code>%tensorflow_version 1.x</code> magic:
# <a href="https://colab.research.google.com/notebooks/tensorflow_version.ipynb" target="_blank">more info</a>.</p>

# %%
lungs_image = cv2.imread('/content/drive/My Drive/2d_masks/ID_0001_Z_0146.tif')

# %%
top,right,bottom,left = (140,450,400,48)

# %%
h = lungs_image[top:bottom,left:right]

# %%
plt.imshow(h)

# %%
gray = cv2.cvtColor(h, cv2.COLOR_BGR2GRAY) # convert to grayscale
blur = cv2.blur(gray, (3, 3)) # blur the image
ret, thresh = cv2.threshold(blur, 50, 255, cv2.THRESH_BINARY)

# %%
cv2.findContours(thresh,cv2.RETR_TREE,cv2.CHAIN_APPROX_SIMPLE)
# Out:
# ([array([[[ 46,   0]],
#
#          [[ 46,   1]],
#
#          [[ 44,   3]],
#
#          [[ 43,   3]],
#
#          [[ 41,   5]],
#
#          [[ 40,   5]],
#
#          [[ 21,  24]],
#
#          [[ 20,  24]],
#
#          [[ 19,  25]],
#
#          [[ 18,  25]],
#
#          [[  9,  34]],
#
#          [[  9,  36]],
#
#          [[  7,  38]],
#
#          [[  7,  39]],
#
#          [[  6,  40]],
#
#          [[  6,  41]],
#
#          [[  3,  44]],
#
#          [[  3,  47]],
#
#          [[  2,  48]],
#
#          [[  2,  49]],
#
#          [[  1,  50]],
#
#          [[  1,  51]],
#
#          [[  0,  52]],
#
#          [[  0, 147]],
#
#          [[  1, 147]],
#
#          [[  2, 148]],
#
#          [[  2, 150]],
#
#          [[  3, 151]],
#
#          [[  3, 152]],
#
#          [[  5, 154]],
#
#          [[  5, 157]],
#
#          [[  6, 158]],
#
#          [[  6, 163]],
#
#          [[  7, 164]],
#
#          [[  7, 175]],
#
#          [[  9, 177]],
#
#          [[  9, 179]],
#
# ...

# %%
from numpy import array
im2 = array([[[ 46,   0]],
  
         [[ 46,   1]],
  
         [[ 44,   3]],
  
         [[ 43,   3]],
  
         [[ 41,   5]],
  
         [[ 40,   5]],
  
         [[ 21,  24]],
  
         [[ 20,  24]],
  
         [[ 19,  25]],
  
         [[ 18,  25]],
  
         [[  9,  34]],
  
         [[  9,  36]],
  
         [[  7,  38]],
  
         [[  7,  39]],
  
         [[  6,  40]],
  
         [[  6,  41]],
  
         [[  3,  44]],
  
         [[  3,  47]],
  
         [[  2,  48]],
  
         [[  2,  49]],
  
         [[  1,  50]],
  
         [[  1,  51]],
  
         [[  0,  52]],
  
         [[  0, 147]],
  
         [[  1, 147]],
  
         [[  2, 148]],
  
         [[  2, 150]],
  
         [[  3, 151]],
  
         [[  3, 152]],
  
         [[  5, 154]],
  
         [[  5, 157]],
  
         [[  6, 158]],
  
         [[  6, 163]],
  
         [[  7, 164]],
  
         [[  7, 175]],
  
         [[  9, 177]],
  
         [[  9, 179]],
  
         [[ 11, 181]],
  
         [[ 11, 183]],
  
         [[ 13, 185]],
  
         [[ 13, 187]],
  
         [[ 16, 190]],
  
         [[ 16, 191]],
  
         [[ 20, 195]],
  
         [[ 20, 196]],
  
         [[ 21, 197]],
  
         [[ 21, 198]],
  
         [[ 23, 200]],
  
         [[ 23, 201]],
  
         [[ 25, 203]],
  
         [[ 25, 205]],
  
         [[ 27, 207]],
  
         [[ 27, 209]],
  
         [[ 29, 211]],
  
         [[ 29, 213]],
  
         [[ 30, 214]],
  
         [[ 30, 215]],
  
         [[ 31, 216]],
  
         [[ 31, 218]],
  
         [[ 32, 219]],
  
         [[ 32, 220]],
  
         [[ 33, 221]],
  
         [[ 33, 223]],
  
         [[ 34, 224]],
  
         [[ 34, 226]],
  
         [[ 35, 227]],
  
         [[ 35, 231]],
  
         [[ 37, 233]],
  
         [[ 37, 235]],
  
         [[ 43, 241]],
  
         [[ 43, 243]],
  
         [[ 50, 250]],
  
         [[ 51, 250]],
  
         [[ 54, 253]],
  
         [[ 55, 253]],
  
         [[ 61, 259]],
  
         [[179, 259]],
  
         [[179, 258]],
  
         [[180, 257]],
  
         [[180, 256]],
  
         [[181, 255]],
  
         [[181, 254]],
  
         [[182, 253]],
  
         [[182, 250]],
  
         [[183, 249]],
  
         [[183, 248]],
  
         [[184, 247]],
  
         [[184, 245]],
  
         [[186, 243]],
  
         [[186, 241]],
  
         [[188, 239]],
  
         [[188, 235]],
  
         [[190, 233]],
  
         [[190, 230]],
  
         [[191, 229]],
  
         [[191, 228]],
  
         [[192, 227]],
  
         [[192, 221]],
  
         [[193, 220]],
  
         [[193, 218]],
  
         [[194, 217]],
  
         [[194, 213]],
  
         [[195, 212]],
  
         [[195, 210]],
  
         [[196, 209]],
  
         [[196, 206]],
  
         [[197, 205]],
  
         [[197, 204]],
  
         [[198, 203]],
  
         [[198, 200]],
  
         [[199, 199]],
  
         [[199, 198]],
  
         [[203, 194]],
  
         [[205, 194]],
  
         [[211, 188]],
  
         [[212, 188]],
  
         [[213, 187]],
  
         [[214, 187]],
  
         [[218, 183]],
  
         [[218, 181]],
  
         [[226, 173]],
  
         [[226, 170]],
  
         [[227, 169]],
  
         [[227, 159]],
  
         [[226, 158]],
  
         [[226, 152]],
  
         [[225, 151]],
  
         [[225, 149]],
  
         [[218, 142]],
  
         [[216, 142]],
  
         [[215, 141]],
  
         [[214, 141]],
  
         [[213, 140]],
  
         [[211, 140]],
  
         [[210, 139]],
  
         [[207, 139]],
  
         [[206, 138]],
  
         [[203, 138]],
  
         [[202, 137]],
  
         [[197, 137]],
  
         [[196, 136]],
  
         [[191, 136]],
  
         [[190, 135]],
  
         [[183, 135]],
  
         [[182, 134]],
  
         [[175, 134]],
  
         [[173, 136]],
  
         [[173, 138]],
  
         [[169, 142]],
  
         [[169, 144]],
  
         [[164, 149]],
  
         [[162, 149]],
  
         [[161, 150]],
  
         [[159, 150]],
  
         [[158, 151]],
  
         [[157, 151]],
  
         [[156, 152]],
  
         [[152, 152]],
  
         [[151, 151]],
  
         [[149, 151]],
  
         [[148, 150]],
  
         [[145, 150]],
  
         [[144, 151]],
  
         [[140, 151]],
  
         [[139, 150]],
  
         [[138, 150]],
  
         [[135, 147]],
  
         [[135, 146]],
  
         [[134, 145]],
  
         [[134, 144]],
  
         [[133, 143]],
  
         [[133, 142]],
  
         [[132, 141]],
  
         [[132, 140]],
  
         [[130, 138]],
  
         [[130, 137]],
  
         [[129, 136]],
  
         [[129, 127]],
  
         [[133, 123]],
  
         [[135, 123]],
  
         [[136, 122]],
  
         [[141, 122]],
  
         [[142, 121]],
  
         [[143, 121]],
  
         [[144, 120]],
  
         [[144, 119]],
  
         [[143, 118]],
  
         [[143, 112]],
  
         [[147, 108]],
  
         [[149, 108]],
  
         [[151, 106]],
  
         [[153, 106]],
  
         [[156, 103]],
  
         [[156,  67]],
  
         [[157,  66]],
  
         [[157,  64]],
  
         [[158,  63]],
  
         [[158,  58]],
  
         [[159,  57]],
  
         [[159,  55]],
  
         [[160,  54]],
  
         [[160,  53]],
  
         [[164,  49]],
  
         [[164,  47]],
  
         [[169,  42]],
  
         [[170,  42]],
  
         [[172,  40]],
  
         [[173,  40]],
  
         [[174,  39]],
  
         [[176,  39]],
  
         [[177,  38]],
  
         [[179,  38]],
  
         [[180,  37]],
  
         [[182,  37]],
  
         [[184,  35]],
  
         [[185,  35]],
  
         [[188,  32]],
  
         [[189,  32]],
  
         [[190,  31]],
  
         [[196,  31]],
  
         [[197,  30]],
  
         [[198,  30]],
  
         [[199,  29]],
  
         [[201,  29]],
  
         [[202,  28]],
  
         [[203,  28]],
  
         [[204,  27]],
  
         [[205,  27]],
  
         [[206,  26]],
  
         [[207,  26]],
  
         [[208,  25]],
  
         [[208,  23]],
  
         [[210,  21]],
  
         [[211,  21]],
  
         [[215,  25]],
  
         [[216,  25]],
  
         [[217,  26]],
  
         [[218,  26]],
  
         [[219,  27]],
  
         [[221,  27]],
  
         [[222,  28]],
  
         [[226,  28]],
  
         [[227,  29]],
  
         [[229,  29]],
  
         [[230,  30]],
  
         [[231,  30]],
  
         [[232,  31]],
  
         [[233,  31]],
  
         [[234,  32]],
  
         [[235,  32]],
  
         [[239,  36]],
  
         [[239,  37]],
  
         [[240,  38]],
  
         [[240,  39]],
  
         [[242,  41]],
  
         [[242,  43]],
  
         [[243,  44]],
  
         [[243,  46]],
  
         [[244,  47]],
  
         [[244,  50]],
  
         [[245,  51]],
  
         [[245,  59]],
  
         [[244,  60]],
  
         [[244,  64]],
  
         [[245,  65]],
  
         [[245,  74]],
  
         [[244,  75]],
  
         [[244,  78]],
  
         [[243,  79]],
  
         [[243,  90]],
  
         [[242,  91]],
  
         [[242,  93]],
  
         [[241,  94]],
  
         [[241,  96]],
  
         [[240,  97]],
  
         [[240,  99]],
  
         [[239, 100]],
  
         [[239, 104]],
  
         [[238, 105]],
  
         [[238, 109]],
  
         [[237, 110]],
  
         [[237, 124]],
  
         [[236, 125]],
  
         [[236, 130]],
  
         [[235, 131]],
  
         [[235, 134]],
  
         [[234, 135]],
  
         [[234, 139]],
  
         [[233, 140]],
  
         [[233, 143]],
  
         [[234, 144]],
  
         [[234, 145]],
  
         [[235, 146]],
  
         [[235, 147]],
  
         [[236, 148]],
  
         [[236, 150]],
  
         [[237, 151]],
  
         [[237, 155]],
  
         [[240, 158]],
  
         [[245, 158]],
  
         [[246, 159]],
  
         [[250, 159]],
  
         [[251, 160]],
  
         [[254, 160]],
  
         [[256, 162]],
  
         [[258, 162]],
  
         [[263, 167]],
  
         [[263, 169]],
  
         [[264, 170]],
  
         [[264, 173]],
  
         [[265, 174]],
  
         [[265, 179]],
  
         [[264, 180]],
  
         [[264, 183]],
  
         [[263, 184]],
  
         [[263, 186]],
  
         [[256, 193]],
  
         [[254, 193]],
  
         [[251, 196]],
  
         [[251, 198]],
  
         [[249, 200]],
  
         [[249, 213]],
  
         [[250, 214]],
  
         [[250, 216]],
  
         [[251, 217]],
  
         [[251, 221]],
  
         [[252, 222]],
  
         [[252, 224]],
  
         [[253, 225]],
  
         [[253, 229]],
  
         [[255, 231]],
  
         [[255, 235]],
  
         [[257, 237]],
  
         [[257, 238]],
  
         [[259, 240]],
  
         [[259, 241]],
  
         [[260, 242]],
  
         [[260, 244]],
  
         [[261, 245]],
  
         [[261, 246]],
  
         [[263, 248]],
  
         [[263, 249]],
  
         [[264, 250]],
  
         [[264, 251]],
  
         [[265, 252]],
  
         [[265, 253]],
  
         [[270, 258]],
  
         [[270, 259]],
  
         [[371, 259]],
  
         [[371, 258]],
  
         [[376, 253]],
  
         [[376, 252]],
  
         [[378, 250]],
  
         [[378, 249]],
  
         [[384, 243]],
  
         [[384, 242]],
  
         [[385, 241]],
  
         [[385, 240]],
  
         [[390, 235]],
  
         [[390, 234]],
  
         [[392, 232]],
  
         [[392, 231]],
  
         [[394, 229]],
  
         [[394, 227]],
  
         [[398, 223]],
  
         [[398, 221]],
  
         [[400, 219]],
  
         [[400, 218]],
  
         [[401, 217]],
  
         [[401,  44]],
  
         [[400,  43]],
  
         [[400,  42]],
  
         [[398,  40]],
  
         [[398,  38]],
  
         [[393,  33]],
  
         [[393,  32]],
  
         [[392,  31]],
  
         [[392,  30]],
  
         [[377,  15]],
  
         [[375,  15]],
  
         [[374,  14]],
  
         [[372,  14]],
  
         [[371,  13]],
  
         [[369,  13]],
  
         [[367,  11]],
  
         [[365,  11]],
  
         [[363,   9]],
  
         [[362,   9]],
  
         [[361,   8]],
  
         [[360,   8]],
  
         [[357,   5]],
  
         [[355,   5]],
  
         [[351,   1]],
  
         [[350,   1]],
  
         [[349,   0]]])

# %%
contours =  array([[[269, 141]],
  
         [[273, 141]],
  
         [[274, 142]],
  
         [[276, 142]],
  
         [[281, 147]],
  
         [[281, 149]],
  
         [[278, 152]],
  
         [[272, 152]],
  
         [[271, 151]],
  
         [[269, 151]],
  
         [[266, 148]],
  
         [[266, 144]]])

# %%
hierarchy = array([[[-1, -1,  1, -1],
         [-1, -1, -1,  0]]])

# %%
len(contours)
# Out:
# 12

# %%
hull = []
for i in range(len(contours)):
  hull.append(cv2.convexHull(contours[i],False))

# %%
drawing = np.zeros((thresh.shape[0], thresh.shape[1], 3), np.uint8)
for i in range(len(contours)):
  color_contours = (0, 255, 0) # green - color for contours
  color = (255, 0, 0) # blue - color for convex hull
  cv2.drawContours(drawing, contours, i, color_contours, 1, 8, hierarchy)
  cv2.drawContours(drawing, hull, i, color, 1, 8)
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-16-dcd18b67ea86> in <module>()
#       3   color_contours = (0, 255, 0) # green - color for contours
#       4   color = (255, 0, 0) # blue - color for convex hull
# ----> 5   cv2.drawContours(drawing, contours, i, color_contours, 1, 8, hierarchy)
#       6   cv2.drawContours(drawing, hull, i, color, 1, 8)
#
# error: OpenCV(4.1.2) /io/opencv/modules/imgproc/src/drawing.cpp:2523: error: (-215:Assertion failed) hierarchy.total() == ncontours && hierarchy.type() == CV_32SC4 in function 'drawContours'

# %%
drawing = np.zeros((thresh.shape[0], thresh.shape[1], 3), np.uint8)
color = (255, 0, 0)
for i in range(len(contours)):
  cv2.drawContours(drawing,hull,i,color,1,8)
