# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
import os
from glob import glob
all_images = glob(os.path.join('/content/drive/My Drive/2d_images','*.tif'))

# %%
all_images
# Out:
# ['/content/drive/My Drive/2d_images/ID_0000_Z_0142.tif',
#  '/content/drive/My Drive/2d_images/ID_0008_Z_0065.tif',
#  '/content/drive/My Drive/2d_images/ID_0004_Z_0066.tif',
#  '/content/drive/My Drive/2d_images/ID_0005_Z_0066.tif',
#  '/content/drive/My Drive/2d_images/ID_0009_Z_0114.tif',
#  '/content/drive/My Drive/2d_images/ID_0006_Z_0206.tif',
#  '/content/drive/My Drive/2d_images/ID_0010_Z_0259.tif',
#  '/content/drive/My Drive/2d_images/ID_0007_Z_0211.tif',
#  '/content/drive/My Drive/2d_images/ID_0002_Z_0162.tif',
#  '/content/drive/My Drive/2d_images/ID_0003_Z_0132.tif',
#  '/content/drive/My Drive/2d_images/ID_0011_Z_0156.tif',
#  '/content/drive/My Drive/2d_images/ID_0001_Z_0146.tif',
#  '/content/drive/My Drive/2d_images/ID_0012_Z_0167.tif',
#  '/content/drive/My Drive/2d_images/ID_0020_Z_0070.tif',
#  '/content/drive/My Drive/2d_images/ID_0022_Z_0131.tif',
#  '/content/drive/My Drive/2d_images/ID_0018_Z_0069.tif',
#  '/content/drive/My Drive/2d_images/ID_0016_Z_0208.tif',
#  '/content/drive/My Drive/2d_images/ID_0019_Z_0088.tif',
#  '/content/drive/My Drive/2d_images/ID_0015_Z_0136.tif',
#  '/content/drive/My Drive/2d_images/ID_0014_Z_0116.tif',
#  '/content/drive/My Drive/2d_images/ID_0023_Z_0241.tif',
#  '/content/drive/My Drive/2d_images/ID_0017_Z_0061.tif',
#  '/content/drive/My Drive/2d_images/ID_0021_Z_0066.tif',
#  '/content/drive/My Drive/2d_images/ID_0013_Z_0047.tif',
#  '/content/drive/My Drive/2d_images/ID_0024_Z_0086.tif',
#  '/content/drive/My Drive/2d_images/ID_0032_Z_0055.tif',
#  '/content/drive/My Drive/2d_images/ID_0028_Z_0125.tif',
#  '/content/drive/My Drive/2d_images/ID_0033_Z_0278.tif',
#  '/content/drive/My Drive/2d_images/ID_0034_Z_0066.tif',
#  '/content/drive/My Drive/2d_images/ID_0031_Z_0232.tif',
#  '/content/drive/My Drive/2d_images/ID_0030_Z_0302.tif',
#  '/content/drive/My Drive/2d_images/ID_0026_Z_0140.tif',
#  '/content/drive/My Drive/2d_images/ID_0029_Z_0059.tif',
#  '/content/drive/My Drive/2d_images/ID_0027_Z_0125.tif',
#  '/content/drive/My Drive/2d_images/ID_0025_Z_0112.tif',
#  '/content/drive/My Drive/2d_images/ID_0035_Z_0224.tif',
#  '/content/drive/My Drive/2d_images/ID_0036_Z_0060.tif',
#  '/content/drive/My Drive/2d_images/ID_0044_Z_0116.tif',
#  '/content/drive/My Drive/2d_images/ID_0042_Z_0366.tif',
#  '/content/drive/My Drive/2d_images/ID_0040_Z_0066.tif',
#  '/content/drive/My Drive/2d_images/ID_0039_Z_0112.tif',
#  '/content/drive/My Drive/2d_images/ID_0046_Z_0110.tif',
#  '/content/drive/My Drive/2d_images/ID_0038_Z_0148.tif',
#  '/content/drive/My Drive/2d_images/ID_0043_Z_0097.tif',
#  '/content/drive/My Drive/2d_images/ID_0045_Z_0131.tif',
#  '/content/drive/My Drive/2d_images/ID_0047_Z_0272.tif',
#  '/content/drive/My Drive/2d_images/ID_0041_Z_0336.tif',
#  '/content/drive/My Drive/2d_images/ID_0037_Z_0150.tif',
#  '/content/drive/My Drive/2d_images/ID_0048_Z_0294.tif',
#  '/content/drive/My Drive/2d_images/ID_0056_Z_0163.tif',
#  '/content/drive/My Drive/2d_images/ID_0054_Z_0135.tif',
#  '/content/drive/My Drive/2d_images/ID_0055_Z_0122.tif',
#  '/content/drive/My Drive/2d_images/ID_0058_Z_0150.tif',
#  '/content/drive/My Drive/2d_images/ID_0053_Z_0127.tif',
#  '/content/drive/My Drive/2d_images/ID_0052_Z_0108.tif',
#  '/content/drive/My Drive/2d_images/ID_0051_Z_0130.tif',
#  '/content/drive/My Drive/2d_images/ID_0050_Z_0085.tif',
#  '/content/drive/My Drive/2d_images/ID_0049_Z_0105.tif',
#  '/content/drive/My Drive/2d_images/ID_0057_Z_0070.tif',
#  '/content/drive/My Drive/2d_images/ID_0059_Z_0150.tif',
#  '/content/drive/My Drive/2d_images/ID_0060_Z_0147.tif',
#  '/content/drive/My Drive/2d_images/ID_0062_Z_0125.tif',
#  '/content/drive/My Drive/2d_images/ID_0061_Z_0064.tif',
#  '/content/drive/My Drive/2d_images/ID_0070_Z_0120.tif',
#  '/content/drive/My Drive/2d_images/ID_0068_Z_0055.tif',
#  '/content/drive/My Drive/2d_images/ID_0063_Z_0067.tif',
#  '/content/drive/My Drive/2d_images/ID_0064_Z_0069.tif',
#  '/content/drive/My Drive/2d_images/ID_0069_Z_0054.tif',
#  '/content/drive/My Drive/2d_images/ID_0066_Z_0141.tif',
#  '/content/drive/My Drive/2d_images/ID_0071_Z_0072.tif',
#  '/content/drive/My Drive/2d_images/ID_0065_Z_0126.tif',
#  '/content/drive/My Drive/2d_images/ID_0067_Z_0238.tif',
#  '/content/drive/My Drive/2d_images/ID_0072_Z_0119.tif',
#  '/content/drive/My Drive/2d_images/ID_0080_Z_0213.tif',
#  '/content/drive/My Drive/2d_images/ID_0082_Z_0278.tif',
#  '/content/drive/My Drive/2d_images/ID_0074_Z_0066.tif',
#  '/content/drive/My Drive/2d_images/ID_0073_Z_0076.tif',
#  '/content/drive/My Drive/2d_images/ID_0076_Z_0230.tif',
#  '/content/drive/My Drive/2d_images/ID_0075_Z_0061.tif',
#  '/content/drive/My Drive/2d_images/ID_0078_Z_0058.tif',
#  '/content/drive/My Drive/2d_images/ID_0077_Z_0173.tif',
#  '/content/drive/My Drive/2d_images/ID_0083_Z_0256.tif',
#  '/content/drive/My Drive/2d_images/ID_0081_Z_0066.tif',
#  '/content/drive/My Drive/2d_images/ID_0079_Z_0072.tif',
#  '/content/drive/My Drive/2d_images/ID_0084_Z_0218.tif',
#  '/content/drive/My Drive/2d_images/ID_0086_Z_0253.tif',
#  '/content/drive/My Drive/2d_images/ID_0094_Z_0214.tif',
#  '/content/drive/My Drive/2d_images/ID_0092_Z_0258.tif',
#  '/content/drive/My Drive/2d_images/ID_0095_Z_0097.tif',
#  '/content/drive/My Drive/2d_images/ID_0096_Z_0216.tif',
#  '/content/drive/My Drive/2d_images/ID_0091_Z_0063.tif',
#  '/content/drive/My Drive/2d_images/ID_0093_Z_0123.tif',
#  '/content/drive/My Drive/2d_images/ID_0089_Z_0341.tif',
#  '/content/drive/My Drive/2d_images/ID_0087_Z_0237.tif',
#  '/content/drive/My Drive/2d_images/ID_0088_Z_0100.tif',
#  '/content/drive/My Drive/2d_images/ID_0090_Z_0119.tif',
#  '/content/drive/My Drive/2d_images/ID_0085_Z_0237.tif',
#  '/content/drive/My Drive/2d_images/ID_0097_Z_0098.tif',
#  '/content/drive/My Drive/2d_images/ID_0099_Z_0069.tif',
#  '/content/drive/My Drive/2d_images/ID_0106_Z_0130.tif',
#  '/content/drive/My Drive/2d_images/ID_0107_Z_0062.tif',
#  '/content/drive/My Drive/2d_images/ID_0098_Z_0068.tif',
#  '/content/drive/My Drive/2d_images/ID_0105_Z_0240.tif',
#  '/content/drive/My Drive/2d_images/ID_0100_Z_0062.tif',
#  '/content/drive/My Drive/2d_images/ID_0103_Z_0069.tif',
#  '/content/drive/My Drive/2d_images/ID_0108_Z_0259.tif',
#  '/content/drive/My Drive/2d_images/ID_0101_Z_0196.tif',
#  '/content/drive/My Drive/2d_images/ID_0104_Z_0101.tif',
#  '/content/drive/My Drive/2d_images/ID_0102_Z_0238.tif',
#  '/content/drive/My Drive/2d_images/ID_0109_Z_0134.tif',
#  '/content/drive/My Drive/2d_images/ID_0110_Z_0066.tif',
#  '/content/drive/My Drive/2d_images/ID_0119_Z_0063.tif',
#  '/content/drive/My Drive/2d_images/ID_0115_Z_0060.tif',
#  '/content/drive/My Drive/2d_images/ID_0116_Z_0116.tif',
#  '/content/drive/My Drive/2d_images/ID_0117_Z_0235.tif',
#  '/content/drive/My Drive/2d_images/ID_0111_Z_0078.tif',
#  '/content/drive/My Drive/2d_images/ID_0120_Z_0123.tif',
#  '/content/drive/My Drive/2d_images/ID_0113_Z_0090.tif',
#  '/content/drive/My Drive/2d_images/ID_0114_Z_0078.tif',
#  '/content/drive/My Drive/2d_images/ID_0118_Z_0206.tif',
#  '/content/drive/My Drive/2d_images/ID_0112_Z_0085.tif',
#  '/content/drive/My Drive/2d_images/ID_0121_Z_0245.tif',
#  '/content/drive/My Drive/2d_images/ID_0129_Z_0104.tif',
#  '/content/drive/My Drive/2d_images/ID_0131_Z_0097.tif',
#  '/content/drive/My Drive/2d_images/ID_0125_Z_0119.tif',
#  '/content/drive/My Drive/2d_images/ID_0123_Z_0073.tif',
#  '/content/drive/My Drive/2d_images/ID_0132_Z_0069.tif',
#  '/content/drive/My Drive/2d_images/ID_0130_Z_0140.tif',
#  '/content/drive/My Drive/2d_images/ID_0127_Z_0064.tif',
#  '/content/drive/My Drive/2d_images/ID_0122_Z_0066.tif',
#  '/content/drive/My Drive/2d_images/ID_0124_Z_0066.tif',
#  '/content/drive/My Drive/2d_images/ID_0126_Z_0139.tif',
#  '/content/drive/My Drive/2d_images/ID_0128_Z_0130.tif',
#  '/content/drive/My Drive/2d_images/ID_0133_Z_0070.tif',
#  '/content/drive/My Drive/2d_images/ID_0139_Z_0056.tif',
#  '/content/drive/My Drive/2d_images/ID_0143_Z_0124.tif',
#  '/content/drive/My Drive/2d_images/ID_0137_Z_0155.tif',
#  '/content/drive/My Drive/2d_images/ID_0135_Z_0066.tif',
#  '/content/drive/My Drive/2d_images/ID_0141_Z_0128.tif',
#  '/content/drive/My Drive/2d_images/ID_0144_Z_0224.tif',
#  '/content/drive/My Drive/2d_images/ID_0142_Z_0145.tif',
#  '/content/drive/My Drive/2d_images/ID_0136_Z_0122.tif',
#  '/content/drive/My Drive/2d_images/ID_0134_Z_0137.tif',
#  '/content/drive/My Drive/2d_images/ID_0145_Z_0059.tif',
#  '/content/drive/My Drive/2d_images/ID_0140_Z_0230.tif',
#  '/content/drive/My Drive/2d_images/ID_0138_Z_0063.tif',
#  '/content/drive/My Drive/2d_images/ID_0146_Z_0122.tif',
#  '/content/drive/My Drive/2d_images/ID_0152_Z_0133.tif',
#  '/content/drive/My Drive/2d_images/ID_0156_Z_0099.tif',
#  '/content/drive/My Drive/2d_images/ID_0154_Z_0070.tif',
#  '/content/drive/My Drive/2d_images/ID_0150_Z_0090.tif',
#  '/content/drive/My Drive/2d_images/ID_0155_Z_0130.tif',
#  '/content/drive/My Drive/2d_images/ID_0149_Z_0269.tif',
#  '/content/drive/My Drive/2d_images/ID_0148_Z_0254.tif',
#  '/content/drive/My Drive/2d_images/ID_0157_Z_0070.tif',
#  '/content/drive/My Drive/2d_images/ID_0147_Z_0051.tif',
#  '/content/drive/My Drive/2d_images/ID_0153_Z_0065.tif',
#  '/content/drive/My Drive/2d_images/ID_0151_Z_0140.tif',
#  '/content/drive/My Drive/2d_images/ID_0158_Z_0164.tif',
#  '/content/drive/My Drive/2d_images/ID_0168_Z_0130.tif',
#  '/content/drive/My Drive/2d_images/ID_0166_Z_0072.tif',
#  '/content/drive/My Drive/2d_images/ID_0162_Z_0091.tif',
#  '/content/drive/My Drive/2d_images/ID_0164_Z_0066.tif',
#  '/content/drive/My Drive/2d_images/ID_0169_Z_0066.tif',
#  '/content/drive/My Drive/2d_images/ID_0167_Z_0128.tif',
#  '/content/drive/My Drive/2d_images/ID_0160_Z_0140.tif',
#  '/content/drive/My Drive/2d_images/ID_0165_Z_0145.tif',
#  '/content/drive/My Drive/2d_images/ID_0170_Z_0066.tif',
#  '/content/drive/My Drive/2d_images/ID_0159_Z_0104.tif',
#  '/content/drive/My Drive/2d_images/ID_0161_Z_0075.tif',
#  '/content/drive/My Drive/2d_images/ID_0171_Z_0184.tif',
#  '/content/drive/My Drive/2d_images/ID_0172_Z_0098.tif',
#  '/content/drive/My Drive/2d_images/ID_0163_Z_0138.tif',
#  '/content/drive/My Drive/2d_images/ID_0173_Z_0110.tif',
#  '/content/drive/My Drive/2d_images/ID_0174_Z_0054.tif',
#  '/content/drive/My Drive/2d_images/ID_0183_Z_0242.tif',
#  '/content/drive/My Drive/2d_images/ID_0175_Z_0165.tif',
#  '/content/drive/My Drive/2d_images/ID_0184_Z_0089.tif',
#  '/content/drive/My Drive/2d_images/ID_0178_Z_0127.tif',
#  '/content/drive/My Drive/2d_images/ID_0177_Z_0163.tif',
#  '/content/drive/My Drive/2d_images/ID_0181_Z_0122.tif',
#  '/content/drive/My Drive/2d_images/ID_0180_Z_0086.tif',
#  '/content/drive/My Drive/2d_images/ID_0179_Z_0130.tif',
#  '/content/drive/My Drive/2d_images/ID_0185_Z_0131.tif',
#  '/content/drive/My Drive/2d_images/ID_0176_Z_0162.tif',
#  '/content/drive/My Drive/2d_images/ID_0182_Z_0060.tif',
#  '/content/drive/My Drive/2d_images/ID_0186_Z_0102.tif',
#  '/content/drive/My Drive/2d_images/ID_0188_Z_0137.tif',
#  '/content/drive/My Drive/2d_images/ID_0191_Z_0140.tif',
#  '/content/drive/My Drive/2d_images/ID_0187_Z_0145.tif',
#  '/content/drive/My Drive/2d_images/ID_0196_Z_0259.tif',
#  '/content/drive/My Drive/2d_images/ID_0189_Z_0132.tif',
#  '/content/drive/My Drive/2d_images/ID_0194_Z_0120.tif',
#  '/content/drive/My Drive/2d_images/ID_0193_Z_0060.tif',
#  '/content/drive/My Drive/2d_images/ID_0197_Z_0123.tif',
#  '/content/drive/My Drive/2d_images/ID_0195_Z_0062.tif',
#  '/content/drive/My Drive/2d_images/ID_0192_Z_0064.tif',
#  '/content/drive/My Drive/2d_images/ID_0190_Z_0070.tif',
#  '/content/drive/My Drive/2d_images/ID_0198_Z_0120.tif',
#  '/content/drive/My Drive/2d_images/ID_0200_Z_0125.tif',
#  '/content/drive/My Drive/2d_images/ID_0208_Z_0063.tif',
#  '/content/drive/My Drive/2d_images/ID_0199_Z_0119.tif',
#  '/content/drive/My Drive/2d_images/ID_0201_Z_0241.tif',
#  '/content/drive/My Drive/2d_images/ID_0204_Z_0066.tif',
#  '/content/drive/My Drive/2d_images/ID_0205_Z_0066.tif',
#  '/content/drive/My Drive/2d_images/ID_0207_Z_0160.tif',
#  '/content/drive/My Drive/2d_images/ID_0202_Z_0098.tif',
#  '/content/drive/My Drive/2d_images/ID_0206_Z_0062.tif',
#  '/content/drive/My Drive/2d_images/ID_0209_Z_0267.tif',
#  '/content/drive/My Drive/2d_images/ID_0203_Z_0079.tif',
#  '/content/drive/My Drive/2d_images/ID_0210_Z_0140.tif',
#  '/content/drive/My Drive/2d_images/ID_0217_Z_0078.tif',
#  '/content/drive/My Drive/2d_images/ID_0220_Z_0066.tif',
#  '/content/drive/My Drive/2d_images/ID_0218_Z_0231.tif',
#  '/content/drive/My Drive/2d_images/ID_0213_Z_0088.tif',
#  '/content/drive/My Drive/2d_images/ID_0212_Z_0064.tif',
#  '/content/drive/My Drive/2d_images/ID_0221_Z_0081.tif',
#  '/content/drive/My Drive/2d_images/ID_0222_Z_0122.tif',
#  '/content/drive/My Drive/2d_images/ID_0223_Z_0214.tif',
#  '/content/drive/My Drive/2d_images/ID_0224_Z_0210.tif',
#  '/content/drive/My Drive/2d_images/ID_0225_Z_0069.tif',
#  '/content/drive/My Drive/2d_images/ID_0226_Z_0066.tif',
#  '/content/drive/My Drive/2d_images/ID_0227_Z_0181.tif',
#  '/content/drive/My Drive/2d_images/ID_0228_Z_0097.tif',
#  '/content/drive/My Drive/2d_images/ID_0229_Z_0060.tif',
#  '/content/drive/My Drive/2d_images/ID_0214_Z_0120.tif',
#  '/content/drive/My Drive/2d_images/ID_0216_Z_0057.tif',
#  '/content/drive/My Drive/2d_images/ID_0219_Z_0222.tif',
#  '/content/drive/My Drive/2d_images/ID_0215_Z_0238.tif',
#  '/content/drive/My Drive/2d_images/ID_0211_Z_0140.tif',
#  '/content/drive/My Drive/2d_images/ID_0230_Z_0242.tif',
#  '/content/drive/My Drive/2d_images/ID_0240_Z_0066.tif',
#  '/content/drive/My Drive/2d_images/ID_0238_Z_0253.tif',
#  '/content/drive/My Drive/2d_images/ID_0241_Z_0124.tif',
#  '/content/drive/My Drive/2d_images/ID_0239_Z_0365.tif',
#  '/content/drive/My Drive/2d_images/ID_0234_Z_0096.tif',
#  '/content/drive/My Drive/2d_images/ID_0236_Z_0122.tif',
#  '/content/drive/My Drive/2d_images/ID_0231_Z_0140.tif',
#  '/content/drive/My Drive/2d_images/ID_0235_Z_0058.tif',
#  '/content/drive/My Drive/2d_images/ID_0237_Z_0061.tif',
#  '/content/drive/My Drive/2d_images/ID_0233_Z_0064.tif',
#  '/content/drive/My Drive/2d_images/ID_0232_Z_0063.tif',
#  '/content/drive/My Drive/2d_images/ID_0242_Z_0123.tif',
#  '/content/drive/My Drive/2d_images/ID_0245_Z_0318.tif',
#  '/content/drive/My Drive/2d_images/ID_0247_Z_0070.tif',
#  '/content/drive/My Drive/2d_images/ID_0244_Z_0184.tif',
#  '/content/drive/My Drive/2d_images/ID_0243_Z_0056.tif',
#  '/content/drive/My Drive/2d_images/ID_0251_Z_0125.tif',
#  '/content/drive/My Drive/2d_images/ID_0249_Z_0070.tif',
#  '/content/drive/My Drive/2d_images/ID_0252_Z_0064.tif',
#  '/content/drive/My Drive/2d_images/ID_0248_Z_0062.tif',
#  '/content/drive/My Drive/2d_images/ID_0250_Z_0070.tif',
#  '/content/drive/My Drive/2d_images/ID_0246_Z_0228.tif',
#  '/content/drive/My Drive/2d_images/ID_0253_Z_0238.tif',
#  '/content/drive/My Drive/2d_images/ID_0254_Z_0075.tif',
#  '/content/drive/My Drive/2d_images/ID_0262_Z_0064.tif',
#  '/content/drive/My Drive/2d_images/ID_0264_Z_0080.tif',
#  '/content/drive/My Drive/2d_images/ID_0261_Z_0238.tif',
#  '/content/drive/My Drive/2d_images/ID_0263_Z_0093.tif',
#  '/content/drive/My Drive/2d_images/ID_0258_Z_0072.tif',
#  '/content/drive/My Drive/2d_images/ID_0260_Z_0148.tif',
#  '/content/drive/My Drive/2d_images/ID_0259_Z_0073.tif',
#  '/content/drive/My Drive/2d_images/ID_0257_Z_0071.tif',
#  '/content/drive/My Drive/2d_images/ID_0256_Z_0062.tif',
#  '/content/drive/My Drive/2d_images/ID_0255_Z_0061.tif',
#  '/content/drive/My Drive/2d_images/ID_0265_Z_0063.tif',
#  '/content/drive/My Drive/2d_images/ID_0266_Z_0202.tif']

# %%
all_masks = ['_masks'.join(c_file.split('_images')) for c_file in all_images]

# %%
all_masks
# Out:
# ['/content/drive/My Drive/2d_masks/ID_0000_Z_0142.tif',
#  '/content/drive/My Drive/2d_masks/ID_0008_Z_0065.tif',
#  '/content/drive/My Drive/2d_masks/ID_0004_Z_0066.tif',
#  '/content/drive/My Drive/2d_masks/ID_0005_Z_0066.tif',
#  '/content/drive/My Drive/2d_masks/ID_0009_Z_0114.tif',
#  '/content/drive/My Drive/2d_masks/ID_0006_Z_0206.tif',
#  '/content/drive/My Drive/2d_masks/ID_0010_Z_0259.tif',
#  '/content/drive/My Drive/2d_masks/ID_0007_Z_0211.tif',
#  '/content/drive/My Drive/2d_masks/ID_0002_Z_0162.tif',
#  '/content/drive/My Drive/2d_masks/ID_0003_Z_0132.tif',
#  '/content/drive/My Drive/2d_masks/ID_0011_Z_0156.tif',
#  '/content/drive/My Drive/2d_masks/ID_0001_Z_0146.tif',
#  '/content/drive/My Drive/2d_masks/ID_0012_Z_0167.tif',
#  '/content/drive/My Drive/2d_masks/ID_0020_Z_0070.tif',
#  '/content/drive/My Drive/2d_masks/ID_0022_Z_0131.tif',
#  '/content/drive/My Drive/2d_masks/ID_0018_Z_0069.tif',
#  '/content/drive/My Drive/2d_masks/ID_0016_Z_0208.tif',
#  '/content/drive/My Drive/2d_masks/ID_0019_Z_0088.tif',
#  '/content/drive/My Drive/2d_masks/ID_0015_Z_0136.tif',
#  '/content/drive/My Drive/2d_masks/ID_0014_Z_0116.tif',
#  '/content/drive/My Drive/2d_masks/ID_0023_Z_0241.tif',
#  '/content/drive/My Drive/2d_masks/ID_0017_Z_0061.tif',
#  '/content/drive/My Drive/2d_masks/ID_0021_Z_0066.tif',
#  '/content/drive/My Drive/2d_masks/ID_0013_Z_0047.tif',
#  '/content/drive/My Drive/2d_masks/ID_0024_Z_0086.tif',
#  '/content/drive/My Drive/2d_masks/ID_0032_Z_0055.tif',
#  '/content/drive/My Drive/2d_masks/ID_0028_Z_0125.tif',
#  '/content/drive/My Drive/2d_masks/ID_0033_Z_0278.tif',
#  '/content/drive/My Drive/2d_masks/ID_0034_Z_0066.tif',
#  '/content/drive/My Drive/2d_masks/ID_0031_Z_0232.tif',
#  '/content/drive/My Drive/2d_masks/ID_0030_Z_0302.tif',
#  '/content/drive/My Drive/2d_masks/ID_0026_Z_0140.tif',
#  '/content/drive/My Drive/2d_masks/ID_0029_Z_0059.tif',
#  '/content/drive/My Drive/2d_masks/ID_0027_Z_0125.tif',
#  '/content/drive/My Drive/2d_masks/ID_0025_Z_0112.tif',
#  '/content/drive/My Drive/2d_masks/ID_0035_Z_0224.tif',
#  '/content/drive/My Drive/2d_masks/ID_0036_Z_0060.tif',
#  '/content/drive/My Drive/2d_masks/ID_0044_Z_0116.tif',
#  '/content/drive/My Drive/2d_masks/ID_0042_Z_0366.tif',
#  '/content/drive/My Drive/2d_masks/ID_0040_Z_0066.tif',
#  '/content/drive/My Drive/2d_masks/ID_0039_Z_0112.tif',
#  '/content/drive/My Drive/2d_masks/ID_0046_Z_0110.tif',
#  '/content/drive/My Drive/2d_masks/ID_0038_Z_0148.tif',
#  '/content/drive/My Drive/2d_masks/ID_0043_Z_0097.tif',
#  '/content/drive/My Drive/2d_masks/ID_0045_Z_0131.tif',
#  '/content/drive/My Drive/2d_masks/ID_0047_Z_0272.tif',
#  '/content/drive/My Drive/2d_masks/ID_0041_Z_0336.tif',
#  '/content/drive/My Drive/2d_masks/ID_0037_Z_0150.tif',
#  '/content/drive/My Drive/2d_masks/ID_0048_Z_0294.tif',
#  '/content/drive/My Drive/2d_masks/ID_0056_Z_0163.tif',
#  '/content/drive/My Drive/2d_masks/ID_0054_Z_0135.tif',
#  '/content/drive/My Drive/2d_masks/ID_0055_Z_0122.tif',
#  '/content/drive/My Drive/2d_masks/ID_0058_Z_0150.tif',
#  '/content/drive/My Drive/2d_masks/ID_0053_Z_0127.tif',
#  '/content/drive/My Drive/2d_masks/ID_0052_Z_0108.tif',
#  '/content/drive/My Drive/2d_masks/ID_0051_Z_0130.tif',
#  '/content/drive/My Drive/2d_masks/ID_0050_Z_0085.tif',
#  '/content/drive/My Drive/2d_masks/ID_0049_Z_0105.tif',
#  '/content/drive/My Drive/2d_masks/ID_0057_Z_0070.tif',
#  '/content/drive/My Drive/2d_masks/ID_0059_Z_0150.tif',
#  '/content/drive/My Drive/2d_masks/ID_0060_Z_0147.tif',
#  '/content/drive/My Drive/2d_masks/ID_0062_Z_0125.tif',
#  '/content/drive/My Drive/2d_masks/ID_0061_Z_0064.tif',
#  '/content/drive/My Drive/2d_masks/ID_0070_Z_0120.tif',
#  '/content/drive/My Drive/2d_masks/ID_0068_Z_0055.tif',
#  '/content/drive/My Drive/2d_masks/ID_0063_Z_0067.tif',
#  '/content/drive/My Drive/2d_masks/ID_0064_Z_0069.tif',
#  '/content/drive/My Drive/2d_masks/ID_0069_Z_0054.tif',
#  '/content/drive/My Drive/2d_masks/ID_0066_Z_0141.tif',
#  '/content/drive/My Drive/2d_masks/ID_0071_Z_0072.tif',
#  '/content/drive/My Drive/2d_masks/ID_0065_Z_0126.tif',
#  '/content/drive/My Drive/2d_masks/ID_0067_Z_0238.tif',
#  '/content/drive/My Drive/2d_masks/ID_0072_Z_0119.tif',
#  '/content/drive/My Drive/2d_masks/ID_0080_Z_0213.tif',
#  '/content/drive/My Drive/2d_masks/ID_0082_Z_0278.tif',
#  '/content/drive/My Drive/2d_masks/ID_0074_Z_0066.tif',
#  '/content/drive/My Drive/2d_masks/ID_0073_Z_0076.tif',
#  '/content/drive/My Drive/2d_masks/ID_0076_Z_0230.tif',
#  '/content/drive/My Drive/2d_masks/ID_0075_Z_0061.tif',
#  '/content/drive/My Drive/2d_masks/ID_0078_Z_0058.tif',
#  '/content/drive/My Drive/2d_masks/ID_0077_Z_0173.tif',
#  '/content/drive/My Drive/2d_masks/ID_0083_Z_0256.tif',
#  '/content/drive/My Drive/2d_masks/ID_0081_Z_0066.tif',
#  '/content/drive/My Drive/2d_masks/ID_0079_Z_0072.tif',
#  '/content/drive/My Drive/2d_masks/ID_0084_Z_0218.tif',
#  '/content/drive/My Drive/2d_masks/ID_0086_Z_0253.tif',
#  '/content/drive/My Drive/2d_masks/ID_0094_Z_0214.tif',
#  '/content/drive/My Drive/2d_masks/ID_0092_Z_0258.tif',
#  '/content/drive/My Drive/2d_masks/ID_0095_Z_0097.tif',
#  '/content/drive/My Drive/2d_masks/ID_0096_Z_0216.tif',
#  '/content/drive/My Drive/2d_masks/ID_0091_Z_0063.tif',
#  '/content/drive/My Drive/2d_masks/ID_0093_Z_0123.tif',
#  '/content/drive/My Drive/2d_masks/ID_0089_Z_0341.tif',
#  '/content/drive/My Drive/2d_masks/ID_0087_Z_0237.tif',
#  '/content/drive/My Drive/2d_masks/ID_0088_Z_0100.tif',
#  '/content/drive/My Drive/2d_masks/ID_0090_Z_0119.tif',
#  '/content/drive/My Drive/2d_masks/ID_0085_Z_0237.tif',
#  '/content/drive/My Drive/2d_masks/ID_0097_Z_0098.tif',
#  '/content/drive/My Drive/2d_masks/ID_0099_Z_0069.tif',
#  '/content/drive/My Drive/2d_masks/ID_0106_Z_0130.tif',
#  '/content/drive/My Drive/2d_masks/ID_0107_Z_0062.tif',
#  '/content/drive/My Drive/2d_masks/ID_0098_Z_0068.tif',
#  '/content/drive/My Drive/2d_masks/ID_0105_Z_0240.tif',
#  '/content/drive/My Drive/2d_masks/ID_0100_Z_0062.tif',
#  '/content/drive/My Drive/2d_masks/ID_0103_Z_0069.tif',
#  '/content/drive/My Drive/2d_masks/ID_0108_Z_0259.tif',
#  '/content/drive/My Drive/2d_masks/ID_0101_Z_0196.tif',
#  '/content/drive/My Drive/2d_masks/ID_0104_Z_0101.tif',
#  '/content/drive/My Drive/2d_masks/ID_0102_Z_0238.tif',
#  '/content/drive/My Drive/2d_masks/ID_0109_Z_0134.tif',
#  '/content/drive/My Drive/2d_masks/ID_0110_Z_0066.tif',
#  '/content/drive/My Drive/2d_masks/ID_0119_Z_0063.tif',
#  '/content/drive/My Drive/2d_masks/ID_0115_Z_0060.tif',
#  '/content/drive/My Drive/2d_masks/ID_0116_Z_0116.tif',
#  '/content/drive/My Drive/2d_masks/ID_0117_Z_0235.tif',
#  '/content/drive/My Drive/2d_masks/ID_0111_Z_0078.tif',
#  '/content/drive/My Drive/2d_masks/ID_0120_Z_0123.tif',
#  '/content/drive/My Drive/2d_masks/ID_0113_Z_0090.tif',
#  '/content/drive/My Drive/2d_masks/ID_0114_Z_0078.tif',
#  '/content/drive/My Drive/2d_masks/ID_0118_Z_0206.tif',
#  '/content/drive/My Drive/2d_masks/ID_0112_Z_0085.tif',
#  '/content/drive/My Drive/2d_masks/ID_0121_Z_0245.tif',
#  '/content/drive/My Drive/2d_masks/ID_0129_Z_0104.tif',
#  '/content/drive/My Drive/2d_masks/ID_0131_Z_0097.tif',
#  '/content/drive/My Drive/2d_masks/ID_0125_Z_0119.tif',
#  '/content/drive/My Drive/2d_masks/ID_0123_Z_0073.tif',
#  '/content/drive/My Drive/2d_masks/ID_0132_Z_0069.tif',
#  '/content/drive/My Drive/2d_masks/ID_0130_Z_0140.tif',
#  '/content/drive/My Drive/2d_masks/ID_0127_Z_0064.tif',
#  '/content/drive/My Drive/2d_masks/ID_0122_Z_0066.tif',
#  '/content/drive/My Drive/2d_masks/ID_0124_Z_0066.tif',
#  '/content/drive/My Drive/2d_masks/ID_0126_Z_0139.tif',
#  '/content/drive/My Drive/2d_masks/ID_0128_Z_0130.tif',
#  '/content/drive/My Drive/2d_masks/ID_0133_Z_0070.tif',
#  '/content/drive/My Drive/2d_masks/ID_0139_Z_0056.tif',
#  '/content/drive/My Drive/2d_masks/ID_0143_Z_0124.tif',
#  '/content/drive/My Drive/2d_masks/ID_0137_Z_0155.tif',
#  '/content/drive/My Drive/2d_masks/ID_0135_Z_0066.tif',
#  '/content/drive/My Drive/2d_masks/ID_0141_Z_0128.tif',
#  '/content/drive/My Drive/2d_masks/ID_0144_Z_0224.tif',
#  '/content/drive/My Drive/2d_masks/ID_0142_Z_0145.tif',
#  '/content/drive/My Drive/2d_masks/ID_0136_Z_0122.tif',
#  '/content/drive/My Drive/2d_masks/ID_0134_Z_0137.tif',
#  '/content/drive/My Drive/2d_masks/ID_0145_Z_0059.tif',
#  '/content/drive/My Drive/2d_masks/ID_0140_Z_0230.tif',
#  '/content/drive/My Drive/2d_masks/ID_0138_Z_0063.tif',
#  '/content/drive/My Drive/2d_masks/ID_0146_Z_0122.tif',
#  '/content/drive/My Drive/2d_masks/ID_0152_Z_0133.tif',
#  '/content/drive/My Drive/2d_masks/ID_0156_Z_0099.tif',
#  '/content/drive/My Drive/2d_masks/ID_0154_Z_0070.tif',
#  '/content/drive/My Drive/2d_masks/ID_0150_Z_0090.tif',
#  '/content/drive/My Drive/2d_masks/ID_0155_Z_0130.tif',
#  '/content/drive/My Drive/2d_masks/ID_0149_Z_0269.tif',
#  '/content/drive/My Drive/2d_masks/ID_0148_Z_0254.tif',
#  '/content/drive/My Drive/2d_masks/ID_0157_Z_0070.tif',
#  '/content/drive/My Drive/2d_masks/ID_0147_Z_0051.tif',
#  '/content/drive/My Drive/2d_masks/ID_0153_Z_0065.tif',
#  '/content/drive/My Drive/2d_masks/ID_0151_Z_0140.tif',
#  '/content/drive/My Drive/2d_masks/ID_0158_Z_0164.tif',
#  '/content/drive/My Drive/2d_masks/ID_0168_Z_0130.tif',
#  '/content/drive/My Drive/2d_masks/ID_0166_Z_0072.tif',
#  '/content/drive/My Drive/2d_masks/ID_0162_Z_0091.tif',
#  '/content/drive/My Drive/2d_masks/ID_0164_Z_0066.tif',
#  '/content/drive/My Drive/2d_masks/ID_0169_Z_0066.tif',
#  '/content/drive/My Drive/2d_masks/ID_0167_Z_0128.tif',
#  '/content/drive/My Drive/2d_masks/ID_0160_Z_0140.tif',
#  '/content/drive/My Drive/2d_masks/ID_0165_Z_0145.tif',
#  '/content/drive/My Drive/2d_masks/ID_0170_Z_0066.tif',
#  '/content/drive/My Drive/2d_masks/ID_0159_Z_0104.tif',
#  '/content/drive/My Drive/2d_masks/ID_0161_Z_0075.tif',
#  '/content/drive/My Drive/2d_masks/ID_0171_Z_0184.tif',
#  '/content/drive/My Drive/2d_masks/ID_0172_Z_0098.tif',
#  '/content/drive/My Drive/2d_masks/ID_0163_Z_0138.tif',
#  '/content/drive/My Drive/2d_masks/ID_0173_Z_0110.tif',
#  '/content/drive/My Drive/2d_masks/ID_0174_Z_0054.tif',
#  '/content/drive/My Drive/2d_masks/ID_0183_Z_0242.tif',
#  '/content/drive/My Drive/2d_masks/ID_0175_Z_0165.tif',
#  '/content/drive/My Drive/2d_masks/ID_0184_Z_0089.tif',
#  '/content/drive/My Drive/2d_masks/ID_0178_Z_0127.tif',
#  '/content/drive/My Drive/2d_masks/ID_0177_Z_0163.tif',
#  '/content/drive/My Drive/2d_masks/ID_0181_Z_0122.tif',
#  '/content/drive/My Drive/2d_masks/ID_0180_Z_0086.tif',
#  '/content/drive/My Drive/2d_masks/ID_0179_Z_0130.tif',
#  '/content/drive/My Drive/2d_masks/ID_0185_Z_0131.tif',
#  '/content/drive/My Drive/2d_masks/ID_0176_Z_0162.tif',
#  '/content/drive/My Drive/2d_masks/ID_0182_Z_0060.tif',
#  '/content/drive/My Drive/2d_masks/ID_0186_Z_0102.tif',
#  '/content/drive/My Drive/2d_masks/ID_0188_Z_0137.tif',
#  '/content/drive/My Drive/2d_masks/ID_0191_Z_0140.tif',
#  '/content/drive/My Drive/2d_masks/ID_0187_Z_0145.tif',
#  '/content/drive/My Drive/2d_masks/ID_0196_Z_0259.tif',
#  '/content/drive/My Drive/2d_masks/ID_0189_Z_0132.tif',
#  '/content/drive/My Drive/2d_masks/ID_0194_Z_0120.tif',
#  '/content/drive/My Drive/2d_masks/ID_0193_Z_0060.tif',
#  '/content/drive/My Drive/2d_masks/ID_0197_Z_0123.tif',
#  '/content/drive/My Drive/2d_masks/ID_0195_Z_0062.tif',
#  '/content/drive/My Drive/2d_masks/ID_0192_Z_0064.tif',
#  '/content/drive/My Drive/2d_masks/ID_0190_Z_0070.tif',
#  '/content/drive/My Drive/2d_masks/ID_0198_Z_0120.tif',
#  '/content/drive/My Drive/2d_masks/ID_0200_Z_0125.tif',
#  '/content/drive/My Drive/2d_masks/ID_0208_Z_0063.tif',
#  '/content/drive/My Drive/2d_masks/ID_0199_Z_0119.tif',
#  '/content/drive/My Drive/2d_masks/ID_0201_Z_0241.tif',
#  '/content/drive/My Drive/2d_masks/ID_0204_Z_0066.tif',
#  '/content/drive/My Drive/2d_masks/ID_0205_Z_0066.tif',
#  '/content/drive/My Drive/2d_masks/ID_0207_Z_0160.tif',
#  '/content/drive/My Drive/2d_masks/ID_0202_Z_0098.tif',
#  '/content/drive/My Drive/2d_masks/ID_0206_Z_0062.tif',
#  '/content/drive/My Drive/2d_masks/ID_0209_Z_0267.tif',
#  '/content/drive/My Drive/2d_masks/ID_0203_Z_0079.tif',
#  '/content/drive/My Drive/2d_masks/ID_0210_Z_0140.tif',
#  '/content/drive/My Drive/2d_masks/ID_0217_Z_0078.tif',
#  '/content/drive/My Drive/2d_masks/ID_0220_Z_0066.tif',
#  '/content/drive/My Drive/2d_masks/ID_0218_Z_0231.tif',
#  '/content/drive/My Drive/2d_masks/ID_0213_Z_0088.tif',
#  '/content/drive/My Drive/2d_masks/ID_0212_Z_0064.tif',
#  '/content/drive/My Drive/2d_masks/ID_0221_Z_0081.tif',
#  '/content/drive/My Drive/2d_masks/ID_0222_Z_0122.tif',
#  '/content/drive/My Drive/2d_masks/ID_0223_Z_0214.tif',
#  '/content/drive/My Drive/2d_masks/ID_0224_Z_0210.tif',
#  '/content/drive/My Drive/2d_masks/ID_0225_Z_0069.tif',
#  '/content/drive/My Drive/2d_masks/ID_0226_Z_0066.tif',
#  '/content/drive/My Drive/2d_masks/ID_0227_Z_0181.tif',
#  '/content/drive/My Drive/2d_masks/ID_0228_Z_0097.tif',
#  '/content/drive/My Drive/2d_masks/ID_0229_Z_0060.tif',
#  '/content/drive/My Drive/2d_masks/ID_0214_Z_0120.tif',
#  '/content/drive/My Drive/2d_masks/ID_0216_Z_0057.tif',
#  '/content/drive/My Drive/2d_masks/ID_0219_Z_0222.tif',
#  '/content/drive/My Drive/2d_masks/ID_0215_Z_0238.tif',
#  '/content/drive/My Drive/2d_masks/ID_0211_Z_0140.tif',
#  '/content/drive/My Drive/2d_masks/ID_0230_Z_0242.tif',
#  '/content/drive/My Drive/2d_masks/ID_0240_Z_0066.tif',
#  '/content/drive/My Drive/2d_masks/ID_0238_Z_0253.tif',
#  '/content/drive/My Drive/2d_masks/ID_0241_Z_0124.tif',
#  '/content/drive/My Drive/2d_masks/ID_0239_Z_0365.tif',
#  '/content/drive/My Drive/2d_masks/ID_0234_Z_0096.tif',
#  '/content/drive/My Drive/2d_masks/ID_0236_Z_0122.tif',
#  '/content/drive/My Drive/2d_masks/ID_0231_Z_0140.tif',
#  '/content/drive/My Drive/2d_masks/ID_0235_Z_0058.tif',
#  '/content/drive/My Drive/2d_masks/ID_0237_Z_0061.tif',
#  '/content/drive/My Drive/2d_masks/ID_0233_Z_0064.tif',
#  '/content/drive/My Drive/2d_masks/ID_0232_Z_0063.tif',
#  '/content/drive/My Drive/2d_masks/ID_0242_Z_0123.tif',
#  '/content/drive/My Drive/2d_masks/ID_0245_Z_0318.tif',
#  '/content/drive/My Drive/2d_masks/ID_0247_Z_0070.tif',
#  '/content/drive/My Drive/2d_masks/ID_0244_Z_0184.tif',
#  '/content/drive/My Drive/2d_masks/ID_0243_Z_0056.tif',
#  '/content/drive/My Drive/2d_masks/ID_0251_Z_0125.tif',
#  '/content/drive/My Drive/2d_masks/ID_0249_Z_0070.tif',
#  '/content/drive/My Drive/2d_masks/ID_0252_Z_0064.tif',
#  '/content/drive/My Drive/2d_masks/ID_0248_Z_0062.tif',
#  '/content/drive/My Drive/2d_masks/ID_0250_Z_0070.tif',
#  '/content/drive/My Drive/2d_masks/ID_0246_Z_0228.tif',
#  '/content/drive/My Drive/2d_masks/ID_0253_Z_0238.tif',
#  '/content/drive/My Drive/2d_masks/ID_0254_Z_0075.tif',
#  '/content/drive/My Drive/2d_masks/ID_0262_Z_0064.tif',
#  '/content/drive/My Drive/2d_masks/ID_0264_Z_0080.tif',
#  '/content/drive/My Drive/2d_masks/ID_0261_Z_0238.tif',
#  '/content/drive/My Drive/2d_masks/ID_0263_Z_0093.tif',
#  '/content/drive/My Drive/2d_masks/ID_0258_Z_0072.tif',
#  '/content/drive/My Drive/2d_masks/ID_0260_Z_0148.tif',
#  '/content/drive/My Drive/2d_masks/ID_0259_Z_0073.tif',
#  '/content/drive/My Drive/2d_masks/ID_0257_Z_0071.tif',
#  '/content/drive/My Drive/2d_masks/ID_0256_Z_0062.tif',
#  '/content/drive/My Drive/2d_masks/ID_0255_Z_0061.tif',
#  '/content/drive/My Drive/2d_masks/ID_0265_Z_0063.tif',
#  '/content/drive/My Drive/2d_masks/ID_0266_Z_0202.tif']

# %%
import cv2

# %%
all_image = [cv2.imread(x) for x in all_images]

# %%
all_mask = [cv2.imread(y) for y in all_masks]
