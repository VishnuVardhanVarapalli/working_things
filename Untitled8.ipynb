# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
#essential libraries for data analysis
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
dataset = pd.read_csv('/content/drive/My Drive/datasets/covid19-in-india/HospitalBedsIndia.csv')

# %%
dataset.head()
# Out:
#    Sno                   State/UT  ... NumUrbanHospitals_NHP18  NumUrbanBeds_NHP18
# 0    1  Andaman & Nicobar Islands  ...                       3                 500
# 1    2             Andhra Pradesh  ...                      65               16658
# 2    3          Arunachal Pradesh  ...                      10                 268
# 3    4                      Assam  ...                      50                6198
# 4    5                      Bihar  ...                     103                5936
#
# [5 rows x 12 columns]

# %%
dataset.columns
# Out:
# Index(['Sno', 'State/UT', 'NumPrimaryHealthCenters_HMIS',
#        'NumCommunityHealthCenters_HMIS', 'NumSubDistrictHospitals_HMIS',
#        'NumDistrictHospitals_HMIS', 'TotalPublicHealthFacilities_HMIS',
#        'NumPublicBeds_HMIS', 'NumRuralHospitals_NHP18', 'NumRuralBeds_NHP18',
#        'NumUrbanHospitals_NHP18', 'NumUrbanBeds_NHP18'],
#       dtype='object')

# %%
dataset1 = dataset

# %%
dataset1 = dataset1.drop(['Sno','State/UT'],axis = 1)

# %%
dataset1
# Out:
#    NumPrimaryHealthCenters_HMIS  ...  NumUrbanBeds_NHP18
# 0                            27  ...                 500
# 1                          1417  ...               16658
# 2                           122  ...                 268
# 3                          1007  ...                6198
# 4                          2007  ...                5936
# 5                            40  ...                 778
# 6                           813  ...                4342
# 7                             9  ...                 316
# 8                             4  ...                   0
# 9                           534  ...               24383
# 10                           31  ...                1608
# 11                         1770  ...               20565
# 12                          500  ...                4550
# 13                          516  ...                6734
# 14                          702  ...                4417
# ...

# %%
index = dataset['State/UT']

# %%
dataset1 = dataset1.set_index(index)

# %%
dataset1
# Out:
#                           NumPrimaryHealthCenters_HMIS  ...  NumUrbanBeds_NHP18
# State/UT                                                ...
# Andaman & Nicobar Islands                           27  ...                 500
# Andhra Pradesh                                    1417  ...               16658
# Arunachal Pradesh                                  122  ...                 268
# Assam                                             1007  ...                6198
# Bihar                                             2007  ...                5936
# Chandigarh                                          40  ...                 778
# Chhattisgarh                                       813  ...                4342
# Dadra & Nagar Haveli                                 9  ...                 316
# Daman & Diu                                          4  ...                   0
# Delhi                                              534  ...               24383
# ...

# %%
dataset1.drop(['All India'],inplace = True)

# %%
dataset1 = dataset1.reset_index()

# %%
dataset1.columns
# Out:
# Index(['State/UT', 'NumPrimaryHealthCenters_HMIS',
#        'NumCommunityHealthCenters_HMIS', 'NumSubDistrictHospitals_HMIS',
#        'NumDistrictHospitals_HMIS', 'TotalPublicHealthFacilities_HMIS',
#        'NumPublicBeds_HMIS', 'NumRuralHospitals_NHP18', 'NumRuralBeds_NHP18',
#        'NumUrbanHospitals_NHP18', 'NumUrbanBeds_NHP18'],
#       dtype='object')

# %%
dataset1.isnull().sum()
# Out:
# State/UT                            0
# NumPrimaryHealthCenters_HMIS        0
# NumCommunityHealthCenters_HMIS      0
# NumSubDistrictHospitals_HMIS        7
# NumDistrictHospitals_HMIS           0
# TotalPublicHealthFacilities_HMIS    0
# NumPublicBeds_HMIS                  0
# NumRuralHospitals_NHP18             0
# NumRuralBeds_NHP18                  0
# NumUrbanHospitals_NHP18             0
# NumUrbanBeds_NHP18                  0
# dtype: int64

# %%
dataset1['NumSubDistrictHospitals_HMIS'].fillna(1.0,inplace = True)

# %%
dataset1.isnull().any()
# Out:
# State/UT                            False
# NumPrimaryHealthCenters_HMIS        False
# NumCommunityHealthCenters_HMIS      False
# NumSubDistrictHospitals_HMIS        False
# NumDistrictHospitals_HMIS           False
# TotalPublicHealthFacilities_HMIS    False
# NumPublicBeds_HMIS                  False
# NumRuralHospitals_NHP18             False
# NumRuralBeds_NHP18                  False
# NumUrbanHospitals_NHP18             False
# NumUrbanBeds_NHP18                  False
# dtype: bool

# %%
city=dataset1['State/UT']#['Delhi','Beijing','Washington','Tokyo','Moscow']
Gender=['NumPrimaryHealthCenters_HMIS','NumCommunityHealthCenters_HMIS',/
        'NumSubDistrictHospitals_HMIS','NumDistrictHospitals_HMIS','TotalPublicHealthFacilities_HMIS'/
        /,'NumPublicBeds_HMIS','NumRuralHospitals_NHP18','NumRuralBeds_NHP18','NumUrbanHospitals_NHP18',/
        /'NumUrbanBeds_NHP18']
pos = np.arange(len(city))
NumPrimaryHealthCenters_HMIS = dataset1['NumPrimaryHealthCenters_HMIS']
NumCommunityHealthCenters_HMIS = dataset1['NumCommunityHealthCenters_HMIS']
NumSubDistrictHospitals_HMIS = dataset1['NumSubDistrictHospitals_HMIS']
NumDistrictHospitals_HMIS = dataset1['NumDistrictHospitals_HMIS']
TotalPublicHealthFacilities_HMIS = dataset1['TotalPublicHealthFacilities_HMIS']
NumPublicBeds_HMIS = dataset1['NumPublicBeds_HMIS']
NumRuralHospitals_NHP18 = dataset1['NumRuralHospitals_NHP18']
NumRuralBeds_NHP18 = dataset1['NumRuralBeds_NHP18']
NumUrbanHospitals_NHP18 = dataset1['NumUrbanHospitals_NHP18']
NumUrbanBeds_NHP18 = dataset1['NumUrbanBeds_NHP18']
Happiness_Index_Male=[60,40,70,65,85]
Happiness_Index_Female=[30,60,70,55,75]
 
plt.bar(pos,NumPrimaryHealthCenters_HMIS,color='blue',edgecolor='black')
plt.bar(pos,NumCommunityHealthCenters_HMIS,color='blue',edgecolor='black')
plt.bar(pos,NumSubDistrictHospitals_HMIS,color='blue',edgecolor='black')
plt.bar(pos,NumDistrictHospitals_HMIS,color='blue',edgecolor='black')
plt.bar(pos,TotalPublicHealthFacilities_HMIS,color='blue',edgecolor='black')
plt.bar(pos,NumPublicBeds_HMIS,color='blue',edgecolor='black')
plt.bar(pos,NumRuralHospitals_NHP18,color='blue',edgecolor='black')
plt.bar(pos,NumRuralBeds_NHP18,color='blue',edgecolor='black')
plt.bar(pos,NumUrbanHospitals_NHP18,color='blue',edgecolor='black')
plt.bar(pos,NumUrbanBeds_NHP18,color='blue',edgecolor='black')
plt.xticks(pos, city)
plt.xlabel('City', fontsize=16)
plt.ylabel('Happiness_Index', fontsize=16)
plt.title('Stacked Barchart - Happiness index across cities',fontsize=18)
plt.legend(Gender,loc=3)
plt.xticks(rotation = 90)
plt.figure(figsize=(30,30))
plt.show()
# Out:
#   File "<ipython-input-26-3d97f8a64736>", line 2
#     Gender=['NumPrimaryHealthCenters_HMIS','NumCommunityHealthCenters_HMIS',/
#                                                                             ^
# SyntaxError: invalid syntax

# %%
states=dataset1['State/UT']
categories = ['NumRuralBeds_NHP18','NumUrbanBeds_NHP18','NumPublicBeds_HMIS']
pos = np.arange(len(states))
plt.bar(pos,NumPublicBeds_HMIS,color='yellow')
#plt.bar(pos,NumRuralHospitals_NHP18,color='blue',edgecolor='black')
plt.bar(pos,NumRuralBeds_NHP18,color='blue')
#plt.bar(pos,NumUrbanHospitals_NHP18,color='blue',edgecolor='black')
plt.bar(pos,NumUrbanBeds_NHP18,color='black')
plt.xticks(pos, states)
plt.xlabel('States of India', fontsize=16)
plt.ylabel('Urban,Rural and Public beds in India', fontsize=16)
plt.title('state-wise list of Urban,Rural and Public beds in India',fontsize=18)
#plt.legend(categories,loc=1)
plt.xticks(rotation = 90)
plt.show()
# Out:
# blue log represents NumRuralBeds_NHP28

# %%
states=dataset1['State/UT']
categories = ['NumRuralHospitals_NHP18','NumUrbanHospitals_NHP18']
pos = np.arange(len(states))
plt.bar(pos,NumRuralHospitals_NHP18,color='yellow')
#plt.bar(pos,NumRuralHospitals_NHP18,color='blue',edgecolor='black')
plt.bar(pos,NumUrbanHospitals_NHP18,color='blue')
#plt.bar(pos,NumUrbanHospitals_NHP18,color='blue',edgecolor='black')
#plt.bar(pos,NumUrbanBeds_NHP18,color='black')
plt.xticks(pos, states)
plt.xlabel('States of India', fontsize=16)
plt.ylabel('Urban & Rural Hospitals in India', fontsize=16)
plt.title('list of Urban,Rural Hospitals in India',fontsize=18)
#plt.legend(categories,loc=1)
plt.xticks(rotation = 90)
plt.show()

# %%
plt.bar(pos,TotalPublicHealthFacilities_HMIS,color='blue')
plt.xticks(pos, states)
plt.xlabel('States of India', fontsize=16)
plt.ylabel('Public Facilities in India', fontsize=16)
plt.title('Total Public Facilities in India',fontsize=18)
#plt.legend(categories,loc=1)
plt.xticks(rotation = 90)
plt.show()
