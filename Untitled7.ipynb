# %%
a = []
while(1):
  a.append('2')

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
#nessasary libraries 
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
dataset = pd.read_csv('/content/drive/My Drive/datasets/music recommendation system/final_dataset.csv')

# %%
dataset['target'].value_counts()
#as both classes are of somwhat same size, we'll use G-mean metric to calucate accuracy
#so performace measure is 'G-mean'
# Out:
# 1.0    3714610
# 0.0    3662694
# Name: target, dtype: int64

# %%
dataset.columns
# Out:
# Index(['Unnamed: 0', 'msno', 'song_id', 'source_system_tab',
#        'source_screen_name', 'source_type', 'target', 'source', 'id', 'city',
#        'bd', 'gender', 'artist_name', 'composer', 'lyricist', 'language'],
#       dtype='object')

# %%
dataset.head()
# Out:
#    Unnamed: 0                                          msno  ... lyricist language
# 0           0  FGtllVqz18RPiwJj/edr2gV78zirAiY/9SmYvia+kCg=  ...      NaN     52.0
# 1           1  FGtllVqz18RPiwJj/edr2gV78zirAiY/9SmYvia+kCg=  ...      NaN     52.0
# 2           2  pouJqjNRmZOnRNzzMWWkamTKkIGHyvhl/jo4HgbncnM=  ...      NaN     52.0
# 3           3  xbodnNBaLMyqqI7uFJlvHOKMJaizuWo/BB/YHZICcKo=  ...      NaN     52.0
# 4           4  s0ndDsjI79amU0RBiullFN8HRz9HjE++34jGNa7zJ/s=  ...      NaN     52.0
#
# [5 rows x 16 columns]

# %%
#assumptions from our data
#let's divide every feature into 3 classes = 'high_impact','low_impact','medium_impact' which implies the effect of every feature on taget vairable
Index(['Unnamed: 0', 'msno', 'song_id', 'source_system_tab',
       'source_screen_name', 'source_type', 'target', 'source', 'id', 'city',
       'bd', 'gender', 'artist_name', 'composer', 'lyricist', 'language'],
      dtype='object')
