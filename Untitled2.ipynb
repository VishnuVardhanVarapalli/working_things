# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
from glob import glob
import os
all_images = glob(os.path.join('/content/drive/My Drive/2d_images', '*.tif'))
all_masks = ['_masks'.join(c_file.split('_images')) for c_file in all_images]

# %%
import cv2
all_image = [cv2.imread(x) for x in all_images]

# %%
all_mask = [cv2.imread(c) for c in all_masks]

# %%
import matplotlib.pyplot as plt

# %%
plt.imshow(all_image[1])

# %%
from skimage.io import imread

# %%
all_im = [imread(x) for x in all_images]

# %%
all_ma = [imread(x) for x in all_masks]

# %%
plt.imshow(all_im[1])

# %%
plt.imshow(all_ma[1])

# %%
plt.imshow(all_ma[3])

# %%
# Out:
# '/content/drive/My Drive/2d_images/ID_0008_Z_0065.tif'
