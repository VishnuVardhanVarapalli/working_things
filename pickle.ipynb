# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
import pickle

# %%
with open('/content/drive/My Drive/annotation_training.pickle','rb') as file:
  for k in file.values:
    print(keys)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-14-07ab73046c09> in <module>()
#       1 with open('/content/drive/My Drive/annotation_training.pickle','rb') as file:
# ----> 2   for k in file.values:
#       3     print(keys)
#
# AttributeError: '_io.BufferedReader' object has no attribute 'values'

# %%
import io
with io.open("/content/drive/My Drive/annotation_training.pickle", "r", encoding="utf-8") as my_file:
     my_unicode_string = my_file.read()
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# <ipython-input-10-4f271b58360b> in <module>()
#       1 import io
#       2 with io.open("/content/drive/My Drive/annotation_training.pickle", "r", encoding="utf-8") as my_file:
# ----> 3      my_unicode_string = my_file.read()
#
# /usr/lib/python3.6/codecs.py in decode(self, input, final)
#     319         # decode input (taking the buffer into account)
#     320         data = self.buffer + input
# --> 321         (result, consumed) = self._buffer_decode(data, self.errors, final)
#     322         # keep undecoded input until the next call
#     323         self.buffer = data[consumed:]
#
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0x80 in position 0: invalid start byte

# %%
with open('/content/drive/My Drive/annotation_training.pkl', 'r',encoding="utf-8") as f:
    x = pickle.load(f)
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# <ipython-input-16-29c1e9a95cd9> in <module>()
#       1 with open('/content/drive/My Drive/annotation_training.pkl', 'r',encoding="utf-8") as f:
# ----> 2     x = pickle.load(f)
#
# /usr/lib/python3.6/codecs.py in decode(self, input, final)
#     319         # decode input (taking the buffer into account)
#     320         data = self.buffer + input
# --> 321         (result, consumed) = self._buffer_decode(data, self.errors, final)
#     322         # keep undecoded input until the next call
#     323         self.buffer = data[consumed:]
#
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0x80 in position 0: invalid start byte
