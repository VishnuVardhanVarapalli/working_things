# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
# !unzip '/content/drive/My Drive/datasets/hand-written-detection.zip' -d '/content/drive/My Drive/datasets/hand_written_detection'
# Out:
# Archive:  /content/drive/My Drive/datasets/hand-written-detection.zip
# 97c2512f593760b14669b37a159ead2f1e54961b
#    creating: /content/drive/My Drive/datasets/hand_written_detection/SimpleHTR-master/
#   inflating: /content/drive/My Drive/datasets/hand_written_detection/SimpleHTR-master/.gitignore
#   inflating: /content/drive/My Drive/datasets/hand_written_detection/SimpleHTR-master/LICENSE.md
#   inflating: /content/drive/My Drive/datasets/hand_written_detection/SimpleHTR-master/README.md
#    creating: /content/drive/My Drive/datasets/hand_written_detection/SimpleHTR-master/data/
#   inflating: /content/drive/My Drive/datasets/hand_written_detection/SimpleHTR-master/data/Get IAM training data.txt
#  extracting: /content/drive/My Drive/datasets/hand_written_detection/SimpleHTR-master/data/analyze.png
#   inflating: /content/drive/My Drive/datasets/hand_written_detection/SimpleHTR-master/data/checkDirs.py
# ...

# %%
# !unzip '/content/drive/My Drive/datasets/hand_written_detection/SimpleHTR-master/model/model.zip' -d '/content/drive/My Drive/datasets/hand_written_detection/SimpleHTR-master/model'
# Out:
# Archive:  /content/drive/My Drive/datasets/hand_written_detection/SimpleHTR-master/model/model.zip
#   inflating: /content/drive/My Drive/datasets/hand_written_detection/SimpleHTR-master/model/checkpoint
#   inflating: /content/drive/My Drive/datasets/hand_written_detection/SimpleHTR-master/model/snapshot-38.data-00000-of-00001
#   inflating: /content/drive/My Drive/datasets/hand_written_detection/SimpleHTR-master/model/snapshot-38.index
#   inflating: /content/drive/My Drive/datasets/hand_written_detection/SimpleHTR-master/model/snapshot-38.meta
